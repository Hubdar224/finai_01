# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
phool = sns.load_dataset("iris")
phool
# draw a line plot 
sns.barplot(x="species", y="petal_length", data=phool)
plt.title("pholon ka plot")


plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a line plot 
sns.barplot(x="sex", y="alone", hue="who", data=boat)



plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a line plot 
sns.barplot(x="sex", y="alone", hue="who", data=boat, order=["female", "male"])



plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a line plot 
sns.barplot(x="sex", y="alone", hue="who", data=boat, order=["female", "male"], color="blue")



plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a line plot 
sns.barplot(x="sex", y="alone", hue="who", data=boat, order=["female", "male"], color="blue", ci=None)



plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a line plot 
sns.barplot(x="sex", y="alone", hue="who", data=boat, order=["female", "male"], color="blue", ci=None, palette="pastel")



plt.show()

# %%
# import libraries
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a bar plot 
sns.barplot(x="class", y="fare", hue="sex", data=boat, color="blue", ci=None, palette="pastel", estimator=median)



plt.show()

# %%
# import libraries
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a bar plot 
sns.barplot(x="class", y="fare", hue="sex", data=boat, color="blue", ci=None, palette="pastel", estimator=median, saturation=10)



plt.show()

# %%
# horizontal plot
# import libraries
import seaborn as sns
 

# load dataset
boat = sns.load_dataset("titanic")
boat
# draw a bar plot 
sns.barplot(x="fare", y="class", hue="sex", data=boat, color="blue", ci=None, palette="pastel", estimator=median, saturation=100)



plt.show()

# %%
# importing the required library
import seaborn as sns
import matplotlib.pyplot as plt

# read a titanic.csv file
# from seaborn library
boat = sns.load_dataset("titanic")
boat
# draw a bar plot 
sns.barplot(x="class", y="fare", data=boat, linewidth=5, facecolor=(0.2, 0.3, 0.4, 0.2), errcolor=".5", edgecolor=".1")
